# %%
import numpy as np
import os
from os.path import isfile
import keras
from keras.models import Sequential, Model
from keras.layers import Input, Dense, TimeDistributed, LSTM, Dropout, Activation
from keras.layers import Conv1D, MaxPooling1D, Flatten, Conv2D, BatchNormalization, Lambda
from keras.layers.advanced_activations import ELU
from keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from keras import backend
from keras.utils import np_utils
from keras.optimizers import Adam, RMSprop

from keras import regularizers


import librosa
import librosa.display
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Load training and Validation arrays

# %%
dict_genres = {'Electronic':0, 'Experimental':1, 'Folk':2, 'Hip-Hop':3, 
               'Instrumental':4,'International':5, 'Pop' :6, 'Rock': 7  }


reverse_map = {v: k for k, v in dict_genres.items()}
print(reverse_map)
# Out:
# {0: 'Electronic', 1: 'Experimental', 2: 'Folk', 3: 'Hip-Hop', 4: 'Instrumental', 5: 'International', 6: 'Pop', 7: 'Rock'}

# %%
npzfile = np.load('dataset/shuffled_train.npz')
print(npzfile.files)
X_train = npzfile['arr_0']
y_train = npzfile['arr_1']
print(X_train.shape, y_train.shape)
# Out:
# ['arr_0', 'arr_1']
# (6394, 640, 128) (6394, 8)

# %%
npzfile = np.load('dataset/shuffled_valid.npz')
print(npzfile.files)
X_valid = npzfile['arr_0']
y_valid = npzfile['arr_1']
print(X_valid.shape, y_valid.shape)
# Out:
# ['arr_0', 'arr_1']
# (800, 640, 128) (800, 8)

# %% [markdown]
# ### Check by plotting a Spectogram

# %%
num = 5300
spectogram = X_train[num]
genre = np.argmax(y_train[num])
print(reverse_map[genre])
plt.figure(figsize=(10, 5))
librosa.display.specshow(spectogram.T, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Test Melspectogram')
plt.tight_layout()
# Out:
# Experimental

# %% [markdown]
# ### CNN - RNN Model

# %%
batch_size = 32
num_classes = 8
n_features = X_train.shape[2]
n_time = X_train.shape[1]

# %%
N_LAYERS = 1
FILTER_LENGTH = 5
CONV_FILTER_COUNT = 56
BATCH_SIZE = 32
LSTM_COUNT = 96
EPOCH_COUNT = 70
NUM_HIDDEN = 64
L2_regularization = 0.001

def conv_recurrent_model_build(model_input):
    print('Building model...')
    layer = model_input
    
    ### 3 1D Convolution Layers
    for i in range(N_LAYERS):
        # give name to the layers
        layer = Conv1D(
                filters=CONV_FILTER_COUNT,
                kernel_size=FILTER_LENGTH,
                kernel_regularizer=regularizers.l2(L2_regularization),  # Tried 0.001
                name='convolution_' + str(i + 1)
            )(layer)
        layer = BatchNormalization(momentum=0.9)(layer)
        layer = Activation('relu')(layer)
        layer = MaxPooling1D(2)(layer)
        layer = Dropout(0.4)(layer)
    
    ## LSTM Layer
    layer = LSTM(LSTM_COUNT, return_sequences=False)(layer)
    layer = Dropout(0.4)(layer)
    
    ## Dense Layer
    layer = Dense(NUM_HIDDEN, kernel_regularizer=regularizers.l2(L2_regularization), name='dense1')(layer)
    layer = Dropout(0.4)(layer)
    
    ## Softmax Output
    layer = Dense(num_classes)(layer)
    layer = Activation('softmax', name='output_realtime')(layer)
    model_output = layer
    model = Model(model_input, model_output)
    
    
    opt = Adam(lr=0.001)
    model.compile(
            loss='categorical_crossentropy',
            optimizer=opt,
            metrics=['accuracy']
        )
    
    print(model.summary())
    return model

# %%
def train_model(x_train, y_train, x_val, y_val):
    
    n_features = x_train.shape[2]
    input_shape = (None, n_features)
    model_input = Input(input_shape, name='input')
    
    model = conv_recurrent_model_build(model_input)
    
#     tb_callback = TensorBoard(log_dir='./logs/4', histogram_freq=1, batch_size=32, write_graph=True, write_grads=False,
#                               write_images=False, embeddings_freq=0, embeddings_layer_names=None,
#                               embeddings_metadata=None)
    checkpoint_callback = ModelCheckpoint('./models/crnn/weights.best.h5', monitor='val_acc', verbose=1,
                                          save_best_only=True, mode='max')
    
    reducelr_callback = ReduceLROnPlateau(
                monitor='val_acc', factor=0.5, patience=10, min_delta=0.01,
                verbose=1
            )
    callbacks_list = [checkpoint_callback, reducelr_callback]

    # Fit the model and get training history.
    print('Training...')
    history = model.fit(x_train, y_train, batch_size=BATCH_SIZE, epochs=EPOCH_COUNT,
                        validation_data=(x_val, y_val), verbose=1, callbacks=callbacks_list)

    return model, history

# %%
def show_summary_stats(history):
    # List all data in history
    print(history.history.keys())

    # Summarize history for accuracy
    plt.plot(history.history['acc'])
    plt.plot(history.history['val_acc'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

# %%
model, history  = train_model(X_train, y_train, X_valid, y_valid)
# Out:
# Building model...
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           (None, None, 128)         0
# _________________________________________________________________
# convolution_1 (Conv1D)       (None, None, 56)          35896
# _________________________________________________________________
# batch_normalization_1 (Batch (None, None, 56)          224
# _________________________________________________________________
# activation_1 (Activation)    (None, None, 56)          0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, None, 56)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, None, 56)          0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 96)                58752
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 96)                0
# _________________________________________________________________
# dense1 (Dense)               (None, 64)                6208
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 520
# _________________________________________________________________
# output_realtime (Activation) (None, 8)                 0
# =================================================================
# Total params: 101,600
# Trainable params: 101,488
# Non-trainable params: 112
# _________________________________________________________________
# None
# Training...
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 6394 samples, validate on 800 samples
# Epoch 1/70
# 6394/6394 [==============================] - 83s 13ms/step - loss: 2.0443 - acc: 0.2820 - val_loss: 2.0584 - val_acc: 0.2150
#
# Epoch 00001: val_acc improved from -inf to 0.21500, saving model to ./models/crnn/weights.best.h5
# Epoch 2/70
# 6394/6394 [==============================] - 68s 11ms/step - loss: 1.9055 - acc: 0.3444 - val_loss: 2.1829 - val_acc: 0.2188
#
# Epoch 00002: val_acc improved from 0.21500 to 0.21875, saving model to ./models/crnn/weights.best.h5
# Epoch 3/70
# 6394/6394 [==============================] - 72s 11ms/step - loss: 1.9067 - acc: 0.3430 - val_loss: 2.0377 - val_acc: 0.2450
#
# Epoch 00003: val_acc improved from 0.21875 to 0.24500, saving model to ./models/crnn/weights.best.h5
# Epoch 4/70
# 6394/6394 [==============================] - 66s 10ms/step - loss: 1.8330 - acc: 0.3672 - val_loss: 1.9948 - val_acc: 0.2850
#
# Epoch 00004: val_acc improved from 0.24500 to 0.28500, saving model to ./models/crnn/weights.best.h5
# Epoch 5/70
# 6394/6394 [==============================] - 68s 11ms/step - loss: 1.8079 - acc: 0.3766 - val_loss: 1.9042 - val_acc: 0.2963
#
# Epoch 00005: val_acc improved from 0.28500 to 0.29625, saving model to ./models/crnn/weights.best.h5
# Epoch 6/70
# 6394/6394 [==============================] - 75s 12ms/step - loss: 1.7991 - acc: 0.3719 - val_loss: 1.8763 - val_acc: 0.2900
#
# Epoch 00006: val_acc did not improve from 0.29625
# Epoch 7/70
# 6394/6394 [==============================] - 74s 12ms/step - loss: 1.8334 - acc: 0.3661 - val_loss: 1.9847 - val_acc: 0.2787
#
# Epoch 00007: val_acc did not improve from 0.29625
# Epoch 8/70
# 6394/6394 [==============================] - 75s 12ms/step - loss: 1.8529 - acc: 0.3466 - val_loss: 1.8880 - val_acc: 0.3312
#
# Epoch 00008: val_acc improved from 0.29625 to 0.33125, saving model to ./models/crnn/weights.best.h5
# Epoch 9/70
# 6394/6394 [==============================] - 73s 11ms/step - loss: 1.8033 - acc: 0.3763 - val_loss: 1.7801 - val_acc: 0.3812
#
# Epoch 00009: val_acc improved from 0.33125 to 0.38125, saving model to ./models/crnn/weights.best.h5
# Epoch 10/70
# 6394/6394 [==============================] - 70s 11ms/step - loss: 1.7618 - acc: 0.3943 - val_loss: 1.8892 - val_acc: 0.3013
#
# Epoch 00010: val_acc did not improve from 0.38125
# Epoch 11/70
# 6394/6394 [==============================] - 68s 11ms/step - loss: 1.7497 - acc: 0.4032 - val_loss: 1.8544 - val_acc: 0.3350
#
# Epoch 00011: val_acc did not improve from 0.38125
# Epoch 12/70
# 6394/6394 [==============================] - 70s 11ms/step - loss: 1.7302 - acc: 0.3997 - val_loss: 1.8186 - val_acc: 0.3262
#
# Epoch 00012: val_acc did not improve from 0.38125
# Epoch 13/70
# 6394/6394 [==============================] - 68s 11ms/step - loss: 1.7385 - acc: 0.3979 - val_loss: 1.8125 - val_acc: 0.3238
#
# Epoch 00013: val_acc did not improve from 0.38125
# Epoch 14/70
# 6394/6394 [==============================] - 64s 10ms/step - loss: 1.6772 - acc: 0.4265 - val_loss: 1.9222 - val_acc: 0.2737
#
# Epoch 00014: val_acc did not improve from 0.38125
# Epoch 15/70
# 6394/6394 [==============================] - 64s 10ms/step - loss: 1.7215 - acc: 0.4077 - val_loss: 1.7840 - val_acc: 0.3738
#
# Epoch 00015: val_acc did not improve from 0.38125
# Epoch 16/70
# 6394/6394 [==============================] - 63s 10ms/step - loss: 1.7272 - acc: 0.4033 - val_loss: 1.8149 - val_acc: 0.3575
#
# Epoch 00016: val_acc did not improve from 0.38125
# Epoch 17/70
# 6394/6394 [==============================] - 63s 10ms/step - loss: 1.6698 - acc: 0.4245 - val_loss: 1.8598 - val_acc: 0.3412
#
# Epoch 00017: val_acc did not improve from 0.38125
# Epoch 18/70
# 6394/6394 [==============================] - 64s 10ms/step - loss: 1.6626 - acc: 0.4337 - val_loss: 1.8348 - val_acc: 0.3225
#
# Epoch 00018: val_acc did not improve from 0.38125
# Epoch 19/70
# 6394/6394 [==============================] - 64s 10ms/step - loss: 1.6594 - acc: 0.4324 - val_loss: 1.8558 - val_acc: 0.3275
#
# Epoch 00019: val_acc did not improve from 0.38125
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 20/70
# 6394/6394 [==============================] - 65s 10ms/step - loss: 1.5954 - acc: 0.4631 - val_loss: 1.9238 - val_acc: 0.2975
#
# Epoch 00020: val_acc did not improve from 0.38125
# Epoch 21/70
# 6394/6394 [==============================] - 65s 10ms/step - loss: 1.5853 - acc: 0.4640 - val_loss: 1.7512 - val_acc: 0.3387
#
# Epoch 00021: val_acc did not improve from 0.38125
# Epoch 22/70
# 6394/6394 [==============================] - 64s 10ms/step - loss: 1.5604 - acc: 0.4815 - val_loss: 1.8000 - val_acc: 0.3362
#
# Epoch 00022: val_acc did not improve from 0.38125
# Epoch 23/70
# 6394/6394 [==============================] - 64s 10ms/step - loss: 1.5524 - acc: 0.4869 - val_loss: 1.7006 - val_acc: 0.3812
#
# Epoch 00023: val_acc did not improve from 0.38125
# Epoch 24/70
# 6394/6394 [==============================] - 64s 10ms/step - loss: 1.5342 - acc: 0.4897 - val_loss: 1.7102 - val_acc: 0.3775
#
# Epoch 00024: val_acc did not improve from 0.38125
# Epoch 25/70
# 6394/6394 [==============================] - 64s 10ms/step - loss: 1.5221 - acc: 0.4933 - val_loss: 1.6562 - val_acc: 0.4000
#
# Epoch 00025: val_acc improved from 0.38125 to 0.40000, saving model to ./models/crnn/weights.best.h5
# Epoch 26/70
# 6394/6394 [==============================] - 64s 10ms/step - loss: 1.5219 - acc: 0.4898 - val_loss: 1.7252 - val_acc: 0.3788
# Epoch 00026: val_acc did not improve from 0.40000
# Epoch 27/70
# 6394/6394 [==============================] - 64s 10ms/step - loss: 1.5334 - acc: 0.4925 - val_loss: 1.7501 - val_acc: 0.3563
#
# Epoch 00027: val_acc did not improve from 0.40000
# Epoch 28/70
# 6394/6394 [==============================] - 77s 12ms/step - loss: 1.4891 - acc: 0.5122 - val_loss: 1.7384 - val_acc: 0.3975
#
# Epoch 00028: val_acc did not improve from 0.40000
# Epoch 29/70
# 6394/6394 [==============================] - 77s 12ms/step - loss: 1.4747 - acc: 0.5089 - val_loss: 1.8288 - val_acc: 0.3538
#
# Epoch 00029: val_acc did not improve from 0.40000
# Epoch 30/70
# 6394/6394 [==============================] - 66s 10ms/step - loss: 1.4805 - acc: 0.5088 - val_loss: 1.6464 - val_acc: 0.4250
#
# Epoch 00030: val_acc improved from 0.40000 to 0.42500, saving model to ./models/crnn/weights.best.h5
# Epoch 31/70
# 6394/6394 [==============================] - 67s 11ms/step - loss: 1.4567 - acc: 0.5170 - val_loss: 1.6565 - val_acc: 0.4175
#
# Epoch 00031: val_acc did not improve from 0.42500
# Epoch 32/70
# 6394/6394 [==============================] - 66s 10ms/step - loss: 1.4336 - acc: 0.5271 - val_loss: 1.7068 - val_acc: 0.4088
#
# Epoch 00032: val_acc did not improve from 0.42500
# Epoch 33/70
# 6394/6394 [==============================] - 66s 10ms/step - loss: 1.4399 - acc: 0.5271 - val_loss: 1.7528 - val_acc: 0.3775
#
# Epoch 00033: val_acc did not improve from 0.42500
# Epoch 34/70
# 6394/6394 [==============================] - 76s 12ms/step - loss: 1.4069 - acc: 0.5388 - val_loss: 2.0651 - val_acc: 0.3387
#
# Epoch 00034: val_acc did not improve from 0.42500
# Epoch 35/70
# 6394/6394 [==============================] - 79s 12ms/step - loss: 1.4211 - acc: 0.5310 - val_loss: 1.6346 - val_acc: 0.4288
#
# Epoch 00035: val_acc improved from 0.42500 to 0.42875, saving model to ./models/crnn/weights.best.h5
# Epoch 36/70
# 6394/6394 [==============================] - 74s 11ms/step - loss: 1.3851 - acc: 0.5507 - val_loss: 1.8572 - val_acc: 0.3412
#
# Epoch 00036: val_acc did not improve from 0.42875
# Epoch 37/70
# 6394/6394 [==============================] - 89s 14ms/step - loss: 1.3873 - acc: 0.5490 - val_loss: 1.6907 - val_acc: 0.3925
#
# Epoch 00037: val_acc did not improve from 0.42875
# Epoch 38/70
# 6394/6394 [==============================] - 82s 13ms/step - loss: 1.3849 - acc: 0.5475 - val_loss: 1.6138 - val_acc: 0.4600
#
# Epoch 00038: val_acc improved from 0.42875 to 0.46000, saving model to ./models/crnn/weights.best.h5
# Epoch 39/70
# 6394/6394 [==============================] - 74s 12ms/step - loss: 1.3606 - acc: 0.5565 - val_loss: 1.6740 - val_acc: 0.4200
#
# Epoch 00039: val_acc did not improve from 0.46000
# Epoch 40/70
# 6394/6394 [==============================] - 73s 11ms/step - loss: 1.3460 - acc: 0.5640 - val_loss: 1.8214 - val_acc: 0.3488
#
# Epoch 00040: val_acc did not improve from 0.46000
# Epoch 41/70
# 6394/6394 [==============================] - 74s 12ms/step - loss: 1.3414 - acc: 0.5588 - val_loss: 1.6411 - val_acc: 0.4200
#
# Epoch 00041: val_acc did not improve from 0.46000
# Epoch 42/70
# 6394/6394 [==============================] - 70s 11ms/step - loss: 1.3349 - acc: 0.5698 - val_loss: 1.8196 - val_acc: 0.3825
#
# Epoch 00042: val_acc did not improve from 0.46000
# Epoch 43/70
# 6394/6394 [==============================] - 71s 11ms/step - loss: 1.3148 - acc: 0.5791 - val_loss: 1.8863 - val_acc: 0.3550
#
# Epoch 00043: val_acc did not improve from 0.46000
# Epoch 44/70
# 6394/6394 [==============================] - 70s 11ms/step - loss: 1.3121 - acc: 0.5699 - val_loss: 1.9721 - val_acc: 0.3100
#
# Epoch 00044: val_acc did not improve from 0.46000
# Epoch 45/70
# 6394/6394 [==============================] - 70s 11ms/step - loss: 1.3255 - acc: 0.5680 - val_loss: 1.8094 - val_acc: 0.3712
#
# Epoch 00045: val_acc did not improve from 0.46000
# Epoch 46/70
# 6394/6394 [==============================] - 71s 11ms/step - loss: 1.3313 - acc: 0.5668 - val_loss: 1.7522 - val_acc: 0.4262
#
# Epoch 00046: val_acc did not improve from 0.46000
# Epoch 47/70
# 6394/6394 [==============================] - 71s 11ms/step - loss: 1.3039 - acc: 0.5794 - val_loss: 1.7875 - val_acc: 0.3850
#
# Epoch 00047: val_acc did not improve from 0.46000
# Epoch 48/70
# 6394/6394 [==============================] - 73s 11ms/step - loss: 1.2864 - acc: 0.5848 - val_loss: 1.7736 - val_acc: 0.4175
#
# Epoch 00048: val_acc did not improve from 0.46000
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 49/70
# 6394/6394 [==============================] - 74s 12ms/step - loss: 1.2401 - acc: 0.6012 - val_loss: 1.7922 - val_acc: 0.3800
#
# Epoch 00049: val_acc did not improve from 0.46000
# Epoch 50/70
# 6394/6394 [==============================] - 72s 11ms/step - loss: 1.2270 - acc: 0.6028 - val_loss: 1.6660 - val_acc: 0.4250
#
# Epoch 00050: val_acc did not improve from 0.46000
# Epoch 51/70
# 6394/6394 [==============================] - 73s 11ms/step - loss: 1.2017 - acc: 0.6157 - val_loss: 1.5804 - val_acc: 0.4662
#
# Epoch 00051: val_acc improved from 0.46000 to 0.46625, saving model to ./models/crnn/weights.best.h5
# Epoch 52/70
# 6394/6394 [==============================] - 73s 11ms/step - loss: 1.2026 - acc: 0.6189 - val_loss: 1.6933 - val_acc: 0.4100
#
# Epoch 00052: val_acc did not improve from 0.46625
# Epoch 53/70
# 6394/6394 [==============================] - 67s 10ms/step - loss: 1.1849 - acc: 0.6218 - val_loss: 1.8413 - val_acc: 0.3475
#
# Epoch 00053: val_acc did not improve from 0.46625
# Epoch 54/70
# 6394/6394 [==============================] - 68s 11ms/step - loss: 1.2009 - acc: 0.6165 - val_loss: 1.8081 - val_acc: 0.4025
#
# Epoch 00054: val_acc did not improve from 0.46625
# Epoch 55/70
# 6394/6394 [==============================] - 69s 11ms/step - loss: 1.1828 - acc: 0.6207 - val_loss: 1.6773 - val_acc: 0.4363
#
# Epoch 00055: val_acc did not improve from 0.46625
# Epoch 56/70
# 6394/6394 [==============================] - 82s 13ms/step - loss: 1.1676 - acc: 0.6347 - val_loss: 1.6473 - val_acc: 0.4525
#
# Epoch 00056: val_acc did not improve from 0.46625
# Epoch 57/70
# 6394/6394 [==============================] - 69s 11ms/step - loss: 1.1694 - acc: 0.6311 - val_loss: 1.8843 - val_acc: 0.3962
#
# Epoch 00057: val_acc did not improve from 0.46625
# Epoch 58/70
# 6394/6394 [==============================] - 67s 11ms/step - loss: 1.1626 - acc: 0.6287 - val_loss: 1.7859 - val_acc: 0.4250
#
# Epoch 00058: val_acc did not improve from 0.46625
#
# Epoch 00058: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 59/70
# 6394/6394 [==============================] - 65s 10ms/step - loss: 1.1268 - acc: 0.6473 - val_loss: 1.6151 - val_acc: 0.4625
#
# Epoch 00059: val_acc did not improve from 0.46625
# Epoch 60/70
# 6394/6394 [==============================] - 69s 11ms/step - loss: 1.1229 - acc: 0.6403 - val_loss: 1.6194 - val_acc: 0.4650
#
# Epoch 00060: val_acc did not improve from 0.46625
# Epoch 61/70
# 6394/6394 [==============================] - 72s 11ms/step - loss: 1.1199 - acc: 0.6478 - val_loss: 1.5956 - val_acc: 0.4650
#
# Epoch 00061: val_acc did not improve from 0.46625
# Epoch 62/70
# 6394/6394 [==============================] - 75s 12ms/step - loss: 1.1245 - acc: 0.6447 - val_loss: 1.7232 - val_acc: 0.4413
#
# Epoch 00062: val_acc did not improve from 0.46625
# Epoch 63/70
# 6394/6394 [==============================] - 72s 11ms/step - loss: 1.1093 - acc: 0.6503 - val_loss: 1.6215 - val_acc: 0.4375
#
# Epoch 00063: val_acc did not improve from 0.46625
# Epoch 64/70
# 6394/6394 [==============================] - 67s 10ms/step - loss: 1.1003 - acc: 0.6547 - val_loss: 1.7093 - val_acc: 0.4437
#
# Epoch 00064: val_acc did not improve from 0.46625
# Epoch 65/70
# 6394/6394 [==============================] - 67s 11ms/step - loss: 1.0853 - acc: 0.6562 - val_loss: 1.5577 - val_acc: 0.4863
#
# Epoch 00065: val_acc improved from 0.46625 to 0.48625, saving model to ./models/crnn/weights.best.h5
# Epoch 66/70
# 6394/6394 [==============================] - 72s 11ms/step - loss: 1.0969 - acc: 0.6500 - val_loss: 1.6343 - val_acc: 0.4525
#
# Epoch 00066: val_acc did not improve from 0.48625
# Epoch 67/70
# 6394/6394 [==============================] - 69s 11ms/step - loss: 1.0873 - acc: 0.6605 - val_loss: 1.5961 - val_acc: 0.5000
#
# Epoch 00067: val_acc improved from 0.48625 to 0.50000, saving model to ./models/crnn/weights.best.h5
# Epoch 68/70
# 6394/6394 [==============================] - 76s 12ms/step - loss: 1.0790 - acc: 0.6617 - val_loss: 1.7207 - val_acc: 0.4275
#
# Epoch 00068: val_acc did not improve from 0.50000
# Epoch 69/70
# 6394/6394 [==============================] - 71s 11ms/step - loss: 1.0720 - acc: 0.6591 - val_loss: 1.6048 - val_acc: 0.4763
#
# Epoch 00069: val_acc did not improve from 0.50000
# Epoch 70/70
# 6394/6394 [==============================] - 146s 23ms/step - loss: 1.0842 - acc: 0.6525 - val_loss: 1.7149 - val_acc: 0.4437
#
# Epoch 00070: val_acc did not improve from 0.50000

# %%
show_summary_stats(history)
# Out:
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc', 'lr'])

# %%
from sklearn.metrics import classification_report

y_true = np.argmax(y_valid, axis = 1)
y_pred = model.predict(X_valid)
y_pred = np.argmax(y_pred, axis=1)
labels = [0,1,2,3,4,5,6,7]
target_names = dict_genres.keys()

print(y_true.shape, y_pred.shape)
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# (800,) (800,)
#                precision    recall  f1-score   support
#
#    Electronic       0.34      0.69      0.46       100
#  Experimental       0.40      0.38      0.39       100
#          Folk       0.63      0.59      0.61       100
#       Hip-Hop       0.68      0.30      0.42       100
#  Instrumental       0.49      0.38      0.43       100
# International       0.53      0.56      0.54       100
#           Pop       0.12      0.12      0.12       100
#          Rock       0.68      0.53      0.60       100
#
#     micro avg       0.44      0.44      0.44       800
#     macro avg       0.48      0.44      0.44       800
#  weighted avg       0.48      0.44      0.44       800

# %%
from sklearn.metrics import accuracy_score

print(accuracy_score(y_true, y_pred))
# Out:
# 0.44375

# %% [markdown]
# ### Connect to Test Set

# %%
from keras.models import load_model

weights_path = 'models/crnn/weights.best.h5'
model = load_model(weights_path)

# %%
npzfile = np.load('dataset/test_arr.npz')
print(npzfile.files)
X_test = npzfile['arr_0']
y_test = npzfile['arr_1']
print(X_test.shape, y_test.shape)
# Out:
# ['arr_0', 'arr_1']
# (800, 640, 128) (800,)

# %%
y_test -= 1
print(np.amin(y_test), np.amax(y_test), np.mean(y_test))
# Out:
# 0 7 3.5

# %%
X_test_raw = librosa.core.db_to_power(X_test, ref=1.0)
print(np.amin(X_test_raw), np.amax(X_test_raw), np.mean(X_test_raw))
# Out:
# 1e-08 1.0000000000000016 0.004623813018385694

# %%
X_test = np.log(X_test_raw)


from sklearn.metrics import classification_report

y_true = y_test
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)
labels = [0,1,2,3,4,5,6,7]
target_names = dict_genres.keys()

print(y_true.shape, y_pred.shape)
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# (800,) (800,)
#                precision    recall  f1-score   support
#
#    Electronic       0.66      0.29      0.40       100
#  Experimental       0.26      0.36      0.30       100
#          Folk       0.13      0.15      0.14       100
#       Hip-Hop       0.65      0.75      0.69       100
#  Instrumental       0.47      0.19      0.27       100
# International       0.41      0.29      0.34       100
#           Pop       0.22      0.30      0.25       100
#          Rock       0.50      0.70      0.58       100
#
#     micro avg       0.38      0.38      0.38       800
#     macro avg       0.41      0.38      0.37       800
#  weighted avg       0.41      0.38      0.37       800

# %%
y_test = keras.utils.to_categorical(y_test, num_classes=8)
model.evaluate(X_test, y_test)
# Out:
# 800/800 [==============================] - 2s 3ms/step
# [1.9194669818878174, 0.37875]

# %%
from sklearn.metrics import confusion_matrix

print(confusion_matrix(y_true, y_pred))
# Out:
# [[29  7  7 11  3 12 29  2]
#  [ 5 36 18  3  6  5 14 13]
#  [ 0 42 15  0  6  4 20 13]
#  [ 1  8  2 75  0  6  6  2]
#  [ 1 27 31  1 19  3  8 10]
#  [ 1  1 22  8  3 29 25 11]
#  [ 7  3 14 16  1  9 30 20]
#  [ 0 13  5  2  2  2  6 70]]

# %%
from sklearn.metrics import accuracy_score

print(accuracy_score(y_true, y_pred))
# Out:
# 0.37875

# %%
### 8 clusters
from sklearn.metrics import confusion_matrix
import seaborn as sns


mat = confusion_matrix(y_true, y_pred)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False,
            xticklabels=dict_genres.keys(),
            yticklabels=dict_genres.keys())
plt.xlabel('true label')
plt.ylabel('predicted label');
